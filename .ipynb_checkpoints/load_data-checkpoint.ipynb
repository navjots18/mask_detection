# %%
from PIL import Image
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
for filename in os.listdir("mask"):
    if(filename.endswith(".jpg")):
        img = Image.open("mask/"+filename)
        plt.figure()
        plt.imshow(img)
